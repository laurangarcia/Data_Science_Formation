# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
np.random.seed(20)
var1 = np.random.randint(1, 10, 10) # Dias de vacaciones
var2 = var1 + np.random.normal(0, 1, 10) # Dinero gastado

# %%
print(var1)
print(var2)
# Out:
# [4 5 7 8 3 1 7 9 6 4]
# [4.93946935 4.02151896 7.50309684 8.40641447 3.32346101 0.50658912
#  6.20798321 8.15763207 4.72049734 4.24571517]

# %% [markdown]
# ## Visualización de resultados con un intervalo de confianza del 80%
