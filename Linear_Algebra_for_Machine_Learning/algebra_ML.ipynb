# %%
# %run "graficarVectores.py"

# %%
from graficarVectores import graficarVectores

# %%
# %matplotlib  inline
 # Nos muestre los graficos dfebajo de cada una de nuestras celdas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[-1, 3], [2, -2]])
print(A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
vector = np.array([[2],[1]])
print(vector)
# Out:
# [[2]
#  [1]]

# %%
print(vector.flatten())
# Out:
# [2 1]

# %%
print(A)
print(A.flatten())
# Out:
# [[-1  3]
#  [ 2 -2]]
# [-1  3  2 -2]

# %%
graficarVectores([vector.flatten()], cols = ["blue"])

plt.xlim(-0.5, 3)
plt.ylim(-0.5, 2)
# Out:
# (-0.5, 2.0)

# %%
vector_transformado = A.dot(vector)
print(vector_transformado)

graficarVectores([vector.flatten(), vector_transformado.flatten()],
                 cols = ["purple", "pink"])
plt.xlim(-0.5, 2.5)
plt.ylim(-0.5, 2.2)

print(np.linalg.det(A))

print(np.linalg.norm(vector))
print(np.linalg.norm(vector_transformado))
# Out:
# [[1]
#  [2]]
# -4.0
# 2.23606797749979
# 2.23606797749979
